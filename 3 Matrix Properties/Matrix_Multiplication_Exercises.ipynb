# %% [markdown]
# **Matrix** **Multiplication** **Exercises**

# %%
import numpy as np
import torch
X = np.array([[23, 5], [3, 21], [6, 7]])
X
# Out:
# array([[23,  5],
#        [ 3, 21],
#        [ 6,  7]])

# %%
X*5
# Out:
# array([[115,  25],
#        [ 15, 105],
#        [ 30,  35]])

# %%
X_p = torch.tensor([[26,7],[28,4],[15,17]])
X_p
# Out:
# tensor([[26,  7],
#         [28,  4],
#         [15, 17]])

# %%
X_p*15+5
# Out:
# tensor([[395, 110],
#         [425,  65],
#         [230, 260]])

# %%
B = np.array([[2, 4], [8, 2], [6, 4]])
B
# Out:
# array([[2, 4],
#        [8, 2],
#        [6, 4]])

# %% [markdown]
# perkalian matrix dengan vektor

# %%
b = np.array([8,2])
b
# Out:
# array([8, 2])

# %%
np.dot(X, b)
# Out:
# array([194,  66,  62])

# %%
b_p = torch.tensor([2,8])
b_p
# Out:
# tensor([2, 8])

# %%
torch.matmul(X_p, b_p)
# Out:
# tensor([108,  88, 166])

# %% [markdown]
# perkalian dengan matrix 2x2

# %%
C = np.array([[8,5],[5,4]])
C
# Out:
# array([[8, 5],
#        [5, 4]])

# %%
np.dot(B,C)
# Out:
# array([[36, 26],
#        [74, 48],
#        [68, 46]])

# %%
B_p = torch.tensor([[17,12],[10,5]])
B_p
# Out:
# tensor([[17, 12],
#         [10,  5]])

# %%
torch.matmul(X_p,B_p)
# Out:
# tensor([[512, 347],
#         [516, 356],
#         [425, 265]])
