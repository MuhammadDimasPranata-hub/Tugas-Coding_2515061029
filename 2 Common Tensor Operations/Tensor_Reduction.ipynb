# %%
# buat matrix X dengan ukuran 2x3 menggunakan numpy

# %%
import numpy as np

# %%
X = np.array([[85,8, 58], [88,58,85]])
X
# Out:
# array([[85,  8, 58],
#        [88, 58, 85]])

# %%
# hitung berapa hasil penjumlahan elemen matrix X dengan fungsi sum

# %%
X.sum()
# Out:
# np.int64(382)

# %%
# buat matrix X_tf dengan ukuran 2x3 menggunakan tensorflow

# %%
import tensorflow as tf

# %%
X_tf = tf.Variable([[85,8, 58], [88,58,85]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[85,  8, 58],
#        [88, 58, 85]], dtype=int32)>

# %%
# hitung hasil penjumlahan seluruh elemen matrix X

# %%
X.sum()
# Out:
# np.int64(382)

# %%
# hitung hasil penjumlahan seluruh elemen matrix X_pt

# %%
import torch

# %%
X_pt = torch.tensor([[85,8, 58], [88,58,85]])
X_pt
# Out:
# tensor([[85,  8, 58],
#         [88, 58, 85]])

# %%
torch.sum(X_pt)
# Out:
# tensor(382)

# %%
# hitung hasil penjumlahan seluruh elemen matrix X_tf

# %%
tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=382>

# %%
# hitung hasil penjumlahan matrix X berdasarkan row nya

# %%
np.sum(X, axis=1)
# Out:
# array([151, 231])

# %%
# hitung hasil penjumlahan matrix X_pt berdasarkan row nya

# %%
torch.sum(X_pt, 1)
# Out:
# tensor([151, 231])

# %%
# hitung hasil penjumlahan matrix X_tf berdasarkan row nya

# %%
tf.reduce_sum(X_tf, 1)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([151, 231], dtype=int32)>

# %%
# hitung hasil penjumlahan matrix X berdasarkan kolom nya

# %%
np.sum(X, axis=0)
# Out:
# array([173,  66, 143])

# %%
# hitung hasil penjumlahan matrix X_pt berdasarkan kolom nya

# %%
torch.sum(X_pt, 0)
# Out:
# tensor([173,  66, 143])

# %%
# hitung hasil penjumlahan matrix X_tf berdasarkan kolom nya

# %%
tf.reduce_sum(X_tf, 0)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([173,  66, 143], dtype=int32)>

# %%
# hitung nilai minimal dari matrix X, X_pt dan X_tf

# %%
np.min(X)
# Out:
# np.int64(8)

# %%
torch.min(X_pt)
# Out:
# tensor(8)

# %%
tf.reduce_min(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=8>

# %%
# hitung nilai maksimal dari matrix X, X_pt dan X_tf

# %%
np.max(X)
# Out:
# np.int64(88)

# %%
torch.max(X_pt)
# Out:
# tensor(88)

# %%
tf.reduce_max(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=88>

# %%
# hitung nilai rata-rata dari matrix X, X_pt dan X_tf

# %%
np.mean(X)
# Out:
# np.float64(63.666666666666664)

# %%
X_pt = X_pt.float()

# %%
torch.mean(X_pt)
# Out:
# tensor(63.6667)

# %%
tf.reduce_mean(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=63>

# %%
# hitung hasil perkalian seluruh elemen matrix X

# %%
np.prod(X)
# Out:
# np.int64(17110649600)

# %%
# hitung hasil perkalian seluruh elemen matrix X_pt

# %%
torch.prod(X_pt)
# Out:
# tensor(1.7111e+10)

# %%
# hitung hasil perkalian seluruh elemen matrix X_tf

# %%
tf.reduce_prod(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=-69219584>
